# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread ('Real Madrid Team.jpg')

#==>If the colors of (the saved image) are like the image below, use those two lines of code

#b,g,r = cv2.split(img)
#img = cv2.merge([r,g,b])


cv2.putText (img,'Campeones',(120,400),7,4,(0,0,0),5)
plt.imshow ( img )
plt.show ( )
cv2.imwrite("Real Madrid-text on.jpg",img)
# Out:
# True
