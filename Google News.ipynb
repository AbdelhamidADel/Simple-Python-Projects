# %%
from GoogleNews import GoogleNews
news = GoogleNews(period='1d')
news.search("مصر")
result = news.result()
import pandas as pd
data = pd.DataFrame.from_dict(result)
data = data.drop(columns=["img"])
data.head()
# Out:
#                                                title                  media  \
# 0  الرئيس السيسي يوافق على تقدم مصر بملف استضافة ...                YouTube
# 1  Sounds of Joy: The Significance of ‘Zaghareet’...       Egyptian Streets
# 2  وزير الزراعة: تقديم أوجه الدعم الفني لمشروع مس...          اخبارنا اليوم
# 3  (Video) Mo Salah’s Egypt brace secures victory...  The Empire of The Kop
# 4  مصر تتنافس على أول لقب لبطولة كرة اليد للكراسي...                YouTube
#
#           date                   datetime  \
# 0   5 mins ago                        NaT
# 1   8 mins ago                        NaT
# 2   1 hour ago 2022-09-24 16:35:13.243977
# 3   1 hour ago 2022-09-24 16:35:13.254974
# 4  3 hours ago 2022-09-24 14:35:13.262180
#
#                                                 desc  \
# 0  الرئيس السيسي يوافق على تقدم مصر بملف استضافة ...
# 1  When words fall short to commemorate a happy o...
# 2  كتب- أحمد مسعد: تفقد السيد القصير، وزير الزراع...
# 3  Mo Salah is the undoubted poster boy of Egypti...
# 4  تتواصل في #مصر النسخة الأولى من بطولة العالم ل...
#
#                                                 link
# 0        https://www.youtube.com/watch?v=ElBWtqv17rU
# 1  https://egyptianstreets.com/2022/09/24/sounds-...
# 2  https://www.akhbarelyaom.com/4031425/%D9%88%D8...
# 3  https://www.empireofthekop.com/2022/09/24/vide...
# 4        https://www.youtube.com/watch?v=ZAqXEiaQ7dU
